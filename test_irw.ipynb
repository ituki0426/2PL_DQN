# %%
# Out:
# 候補数: 11
#
# [1/11] choi_2026_cmsce_2019_2 を確認中...
# [2/11] choi_2026_cmsce_2020_1 を確認中...
# [3/11] choi_2026_cmsce_2021_2 を確認中...
# [4/11] christensen_2018_wsssf_5831 を確認中...
# [5/11] criticalperiod_syntax を確認中...
# [6/11] enem_2014_1mil_cn を確認中...
# [7/11] enem_2018_1mil_cn を確認中...
# [8/11] enem_2025_1mil_lc を確認中...
# [9/11] psychoneurotic_inventory を確認中...
# [10/11] tma を確認中...
# [11/11] vocabulary_iq を確認中...
#
# ...
# 検索結果
# ...
#                        name  n_participants  n_items  density  responses_per_participant          construct_type                                                   construct_name
#       criticalperiod_syntax         1131401       95    1.000                       95.0   Cognitive/educational                                                 Syntax questions
#               vocabulary_iq           12173       75    1.000                       75.0             Personality                                               Vocabulary IQ Test
# ...
